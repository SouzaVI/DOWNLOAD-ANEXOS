# %%
import os
import base64
from typing import List
import time
from google_apis import create_service
from datetime import timedelta
from datetime import date

#today = date.today()
#today_str = today.strftime('%Y/%m/%d')
#yesterday = today - timedelta(1)
#yesterday_str = yesterday.strftime('%Y%m%d')
#os.mkdir("C:/@IGOR/PYCHARM/ANEXOS/" + yesterday.strftime('%Y%m%d'))


class GmailException(Exception):
    """gmail base exception class"""


class NoEmailFound(GmailException):
    """no email found"""


def search_emails(query_string: str, label_ids: List = None):
    try:
        message_list_response = service.users().messages().list(
            userId='me',
            labelIds=label_ids,
            q=query_string
        ).execute()

        message_items = message_list_response.get('messages')
        next_page_token = message_list_response.get('nextPageToken')

        while next_page_token:
            message_list_response = service.users().messages().list(
                userId='me',
                labelIds=label_ids,
                q=query_string,
                pageToken=next_page_token
            ).execute()

            message_items.extend(message_list_response.get('messages'))
            next_page_token = message_list_response.get('nextPageToken')
        return message_items
    except Exception as e:
        raise NoEmailFound('No emails returned')


def get_file_data(message_id, attachment_id, file_name, save_location):
    response = service.users().messages().attachments().get(
        userId='me',
        messageId=message_id,
        id=attachment_id
    ).execute()

    file_data = base64.urlsafe_b64decode(response.get('data').encode('UTF-8'))
    return file_data


def get_message_detail(message_id, msg_format='metadata', metadata_headers: List = None):
    message_detail = service.users().messages().get(
        userId='me',
        id=message_id,
        format=msg_format,
        metadataHeaders=metadata_headers
    ).execute()
    return message_detail


if __name__ == '__main__':
    CLIENT_FILE = 'client_secret.json'
    API_NAME = 'gmail'
    API_VERSION = 'v1'
    SCOPES = ['https://mail.google.com/']
    service = create_service(CLIENT_FILE, API_NAME, API_VERSION, SCOPES)

    query_string = 'has:attachment after:2023/09/01 before:2023/09/22'

    #query_string = 'has:attachment newer_than:1d'
    save_location = ("C:/@IGOR/SETEMBRO")
    email_messages = search_emails(query_string)

    for email_message in email_messages:
        messageDetail = get_message_detail(email_message['id'], msg_format='full', metadata_headers=['parts'])
        messageDetailPayload = messageDetail.get('payload')

        if 'parts' in messageDetailPayload:
            for msgPayload in messageDetailPayload['parts']:
                file_name = msgPayload['filename']
                body = msgPayload['body']
                if 'attachmentId' in body:
                    attachment_id = body['attachmentId']
                    attachment_content = get_file_data(email_message['id'], attachment_id, file_name, save_location)

                    with open(os.path.join(save_location, file_name), 'wb') as _f:
                        _f.write(attachment_content)
                        print(f'File {file_name} is saved at {save_location}')
        time.sleep(0.5)
# Out:
# gmail v1 service created successfully
# File 345045 a 345188 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 345045 a 345188 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 344974 a 345007 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 344974 a 345007 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File WhatsApp Image 2023-09-20 at 17.01.11.jpeg is saved at C:/@IGOR/SETEMBRO
# File Outlook-3n0pus03.png is saved at C:/@IGOR/SETEMBRO
# File 344970 A 344973 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 344970 A 344973 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 348261 a 348277 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 348261 a 348277 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 347317 a 347390 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 347317 a 347390 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 347391 a 347407 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 347391 a 347407 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 347543 A 347605 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 347543 A 347605 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 122863 a 122876 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 122863 a 122876 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 341950 a 342466 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 341950 a 342466 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 346605 a 346639 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 346605 a 346639 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 342928 a 342946 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 342928 a 342946 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 346585 a 346604 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 346585 a 346604 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 342947 a 342961 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 342947 a 342961 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 346576 a 346584 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 346576 a 346584 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 342908 a 342927 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 342908 a 342927 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 346566 a 346575 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 346566 a 346575 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 340914 a 340928 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 340914 a 340928 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 1623 a 1624 RICHARD DE LIMA FERRELL.pdf is saved at C:/@IGOR/SETEMBRO
# File KADMO RIBEIRO CARNEIRO.pdf is saved at C:/@IGOR/SETEMBRO
# File GEISON SCARIOT.pdf is saved at C:/@IGOR/SETEMBRO
# File 346510 A 346565 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 346510 A 346565 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 1685 a 1691 ILMO BOLGENHAGEN.pdf is saved at C:/@IGOR/SETEMBRO
# File 342671 a 342690 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# File 342671 a 342690 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.pdf is saved at C:/@IGOR/SETEMBRO
# File 342467 a 342558 CLÁUDIO JOSÉ RAGAGNIN JUNIOR.xls is saved at C:/@IGOR/SETEMBRO
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 94
#      92 if 'attachmentId' in body:
#      93     attachment_id = body['attachmentId']
# ---> 94     attachment_content = get_file_data(email_message['id'], attachment_id, file_name, save_location)
#      96     with open(os.path.join(save_location, file_name), 'wb') as _f:
#      97         _f.write(attachment_content)
#
# Cell In[1], line 51, in get_file_data(message_id, attachment_id, file_name, save_location)
#      50 def get_file_data(message_id, attachment_id, file_name, save_location):
# ---> 51     response = service.users().messages().attachments().get(
#      52         userId='me',
#      53         messageId=message_id,
#      54         id=attachment_id
#      55     ).execute()
#      57     file_data = base64.urlsafe_b64decode(response.get('data').encode('UTF-8'))
#      58     return file_data
#
# File c:\users\igor.souza\appdata\local\programs\python\python39\lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\users\igor.souza\appdata\local\programs\python\python39\lib\site-packages\googleapiclient\http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
#     926     "request",
#     927     self._sleep,
#     928     self._rand,
#     929     str(self.uri),
#     930     method=str(self.method),
#     931     body=self.body,
#     932     headers=self.headers,
#     933 )
#     935 for callback in self.response_callbacks:
#     936     callback(resp)
#
# File c:\users\igor.souza\appdata\local\programs\python\python39\lib\site-packages\googleapiclient\http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189 try:
#     190     exception = None
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#     192 # Retry on SSL errors and socket timeout errors.
#     193 except _ssl_SSLError as ssl_error:
#
# File c:\users\igor.souza\appdata\local\programs\python\python39\lib\site-packages\google_auth_httplib2.py:218, in AuthorizedHttp.request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     215     body_stream_position = body.tell()
#     217 # Make the request.
# --> 218 response, content = self.http.request(
#     219     uri,
#     220     method,
#     221     body=body,
#     222     headers=request_headers,
#     223     redirections=redirections,
#     224     connection_type=connection_type,
#     225     **kwargs
#     226 )
#     228 # If the response indicated that the credentials needed to be
#     229 # refreshed, then refresh the credentials and re-attempt the
#     230 # request.
#     231 # A stored token may expire between the time it is retrieved and
#     232 # the time the request is made, so we may need to try twice.
#     233 if (
#     234     response.status in self._refresh_status_codes
#     235     and _credential_refresh_attempt < self._max_refresh_attempts
#     236 ):
#
# File c:\users\igor.souza\appdata\local\programs\python\python39\lib\site-packages\httplib2\__init__.py:1724, in Http.request(self, uri, method, body, headers, redirections, connection_type)
#    1722             content = b""
#    1723         else:
# -> 1724             (response, content) = self._request(
#    1725                 conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#    1726             )
#    1727 except Exception as e:
#    1728     is_timeout = isinstance(e, socket.timeout)
#
# File c:\users\igor.souza\appdata\local\programs\python\python39\lib\site-packages\httplib2\__init__.py:1444, in Http._request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1441 if auth:
#    1442     auth.request(method, request_uri, headers, body)
# -> 1444 (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1446 if auth:
#    1447     if auth.response(response, body):
#
# File c:\users\igor.souza\appdata\local\programs\python\python39\lib\site-packages\httplib2\__init__.py:1396, in Http._conn_request(self, conn, request_uri, method, body, headers)
#    1394     pass
#    1395 try:
# -> 1396     response = conn.getresponse()
#    1397 except (http.client.BadStatusLine, http.client.ResponseNotReady):
#    1398     # If we get a BadStatusLine on the first try then that means
#    1399     # the connection just went stale, so retry regardless of the
#    1400     # number of RETRIES set.
#    1401     if not seen_bad_status_line and i == 1:
#
# File c:\users\igor.souza\appdata\local\programs\python\python39\lib\http\client.py:1347, in HTTPConnection.getresponse(self)
#    1345 try:
#    1346     try:
# -> 1347         response.begin()
#    1348     except ConnectionError:
#    1349         self.close()
#
# File c:\users\igor.souza\appdata\local\programs\python\python39\lib\http\client.py:307, in HTTPResponse.begin(self)
#     305 # read until we get a non-100 response
#     306 while True:
# --> 307     version, status, reason = self._read_status()
#     308     if status != CONTINUE:
#     309         break
#
# File c:\users\igor.souza\appdata\local\programs\python\python39\lib\http\client.py:268, in HTTPResponse._read_status(self)
#     267 def _read_status(self):
# --> 268     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269     if len(line) > _MAXLINE:
#     270         raise LineTooLong("status line")
#
# File c:\users\igor.souza\appdata\local\programs\python\python39\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File c:\users\igor.souza\appdata\local\programs\python\python39\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File c:\users\igor.souza\appdata\local\programs\python\python39\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:
